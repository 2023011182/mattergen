# %%
import os
import time
import re
import pandas as pd
from tqdm import tqdm
from math import inf
import sys

from pymatgen.core import Composition
from pymatgen.io.cif import CifWriter

# 尝试导入 mp-api；未安装则提示安装
try:
    from mp_api.client import MPRester
except Exception as e:
    raise ImportError("未安装 mp-api。请先在上方单元执行：%pip install mp-api pymatgen pandas tqdm") from e


def sanitize_filename(name: str, max_len: int = 120) -> str:
    # 替换非法字符并限长
    safe = re.sub(r'[\\/:\"*?<>|]', "_", name).strip().strip(".")
    if len(safe) > max_len:
        base, ext = os.path.splitext(safe)
        safe = (base[:max_len - len(ext) - 1] + "…" + ext) if ext else safe[:max_len]
    # 规避 Windows 保留名
    reserved = {"CON","PRN","AUX","NUL","COM1","COM2","COM3","COM4","COM5","COM6","COM7","COM8","COM9",
                "LPT1","LPT2","LPT3","LPT4","LPT5","LPT6","LPT7","LPT8","LPT9"}
    if safe.upper() in reserved:
        safe = f"_{safe}"
    return safe


def composition_to_search_keys(comp_str: str):
    """
    返回 (reduced_formula, chemsys_str)
    """
    try:
        comp = Composition(comp_str)
        reduced = comp.reduced_formula  # 规范化化学式
        chemsys = "-".join(sorted(el.symbol for el in comp.elements))  # 元素集
        return reduced, chemsys
    except Exception:
        return None, None


def fetch_best_doc(mpr: MPRester, comp_str: str):
    """
    使用公式检索失败则退回按化学体系检索，返回 energy_above_hull 最小的 SummaryDoc
    """
    reduced, chemsys = composition_to_search_keys(comp_str)
    fields = ["material_id", "energy_above_hull", "structure", "formula_pretty"]

    # 先用规范化公式
    docs = []
    if reduced:
        try:
            docs = mpr.summary.search(formula=reduced, fields=fields)
        except Exception:
            docs = []

    # 再用化学体系兜底（不同版本参数名可能不同）
    if not docs and chemsys:
        try:
            docs = mpr.summary.search(chemsys=chemsys, fields=fields)
            if not docs:
                docs = mpr.summary.search(chemical_system=chemsys, fields=fields)
        except Exception:
            docs = []

    if not docs:
        return None

    # 选择最稳（能量最低）
    docs = [d for d in docs if getattr(d, "energy_above_hull", None) is not None]
    if not docs:
        return None
    best = min(docs, key=lambda d: d.energy_above_hull if d.energy_above_hull is not None else inf)
    return best


def download_cif_files(api_key: str, input_csv: str, output_dir: str, sleep_sec: float = 0.2, max_retries: int = 3):
    os.makedirs(output_dir, exist_ok=True)
    print(f"输出目录已创建: {os.path.abspath(output_dir)}")

    # 读取 CSV（前两行是说明文字，真正表头在第三行）
    try:
        df = pd.read_csv(input_csv, header=2)
    except FileNotFoundError:
        print(f"错误: 输入文件 '{input_csv}' 未找到。")
        return
    except Exception as e:
        print(f"读取CSV文件时出错: {e}")
        return

    # 室温筛选
    try:
        rt_df = df[(df['temperature'] >= 15) & (df['temperature'] <= 35)].copy()
        unique_compositions = pd.unique(rt_df['composition'].dropna())
    except Exception as e:
        print(f"数据列缺失或格式异常: {e}")
        return

    print(f"在 '{input_csv}' 中找到 {len(unique_compositions)} 种在室温下的独立化学成分。")

    summary_rows = []

    # 连接 MP
    try:
        mpr = MPRester(api_key)
    except Exception as e:
        print(f"连接到 Materials Project 出错，请检查 API Key 与网络: {e}")
        return

    with mpr:
        with tqdm(total=len(unique_compositions), desc="正在下载CIF文件") as pbar:
            for comp_str in unique_compositions:
                status = "Unknown Error"
                mp_id, e_hull, saved_filename = None, None, None

                # 重试
                last_err = None
                for attempt in range(1, max_retries + 1):
                    try:
                        doc = fetch_best_doc(mpr, comp_str)
                        if not doc:
                            status = "Not Found"
                        else:
                            mp_id = str(doc.material_id)
                            e_hull = doc.energy_above_hull
                            structure = doc.structure  # pymatgen Structure

                            # 写 CIF
                            base_name = f"{sanitize_filename(comp_str)}_{mp_id}.cif"
                            filepath = os.path.join(output_dir, sanitize_filename(base_name))
                            CifWriter(structure).write_file(filepath)
                            saved_filename = os.path.basename(filepath)
                            status = "Success"

                        break  # 成功或确认未找到都跳出重试
                    except Exception as e:
                        last_err = e
                        status = f"Error: {str(e).splitlines()[0]}"
                        time.sleep(sleep_sec * attempt)  # 简单回退
                if status.startswith("Error") and last_err:
                    # 已经记录
                    pass

                summary_rows.append({
                    "original_composition": comp_str,
                    "status": status,
                    "material_id": mp_id,
                    "e_above_hull": e_hull,
                    "saved_filename": saved_filename
                })

                pbar.set_postfix(composition=str(comp_str)[:20], status=status)
                pbar.update(1)
                time.sleep(sleep_sec)  # 速率限制

    # 保存下载摘要
    summary_df = pd.DataFrame(summary_rows)
    summary_path = os.path.join(output_dir, "download_summary.csv")
    summary_df.to_csv(summary_path, index=False)

    success_count = (summary_df['status'] == 'Success').sum()
    failed_count = len(unique_compositions) - success_count

    print("\n" + "=" * 50)
    print("处理完成！")
    print(f"成功下载: {success_count} 个结构的CIF文件")
    print(f"未找到或出错: {failed_count} 个化学成分")
    print(f"所有CIF文件已保存在: {os.path.abspath(output_dir)}")
    print(f"详细下载日志已保存在: {os.path.abspath(summary_path)}")
    print("=" * 50)


# Notebook 直接运行本段即可开始下载；优先使用环境变量，其次使用你提供的密钥
API_KEY = os.getenv("MP_API_KEY") or "LWy9cEJNTrC8Bk1b5QEfsL6EU9tLnZiw"
INPUT_CSV = "LiIonDatabase.csv"
OUTPUT_DIR = "downloaded_cifs"
SLEEP_SEC = 0.2
MAX_RETRIES = 3

download_cif_files(api_key=API_KEY,
                   input_csv=INPUT_CSV,
                   output_dir=OUTPUT_DIR,
                   sleep_sec=SLEEP_SEC,
                   max_retries=MAX_RETRIES)
# Out:
# 输出目录已创建: d:\学习相关文档\大三上\大数据与机器智能\大作业\mattergen\downloaded_cifs
# 在 'LiIonDatabase.csv' 中找到 422 种在室温下的独立化学成分。
# 正在下载CIF文件:   0%|          | 0/422 [00:00<?, ?it/s]C:\Users\11514\AppData\Local\Temp\ipykernel_68424\2177541383.py:57: DeprecationWarning: Accessing summary data through MPRester.summary is deprecated. Please use MPRester.materials.summary instead.
#   docs = mpr.summary.search(formula=reduced, fields=fields)
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# C:\Users\11514\AppData\Local\Temp\ipykernel_68424\2177541383.py:64: DeprecationWarning: Accessing summary data through MPRester.summary is deprecated. Please use MPRester.materials.summary instead.
#   docs = mpr.summary.search(chemsys=chemsys, fields=fields)
# Retrieving SummaryDoc documents: 100%|██████████| 7/7 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]38s/it, composition=Li2OHBr, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]94s/it, composition=Li2.4OH0.6Cl, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]=Li2.1OH0.9Cl, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]33s/it, composition=Li2OHCl, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]=Li2.7OH0.3Cl, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]=Li6PO5Cl, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]03it/s, composition=Li7La3Zr2O12, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]17s/it, composition=Li3.4Si0.4P0.6S4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# C:\Users\11514\AppData\Local\Temp\ipykernel_68424\2177541383.py:66: DeprecationWarning: Accessing summary data through MPRester.summary is deprecated. Please use MPRester.materials.summary instead.
#   docs = mpr.summary.search(chemical_system=chemsys, fields=fields)
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]30s/it, composition=Li6.4La3Zr1.4Ta0.6O1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].39s/it, composition=Li7.06La3Zr1.94Y0.06, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].45s/it, composition=Li6.4Al0.19La3Zr2O1, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 15/15 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].64s/it, composition=La0.57Li0.29TiO3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].62s/it, composition=Li6.5La3Zr1.75Te0.25, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 8/8 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].65s/it, composition=Li9.6P3S12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].62s/it, composition=Li1.3Al0.3Ti1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].62s/it, composition=Li1.2Ti1.8Sc0.2(PO4), status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].60s/it, composition=Li1.6Al0.6Ge0.8(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 14/14 [00:00<?, ?it/s]Li6.55La3Zr2Ga0.9O12, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].39s/it, composition=LiTi2(PO4)3, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 3/3 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]n=Li9.54Si1.74P1.44S11, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]n=Li10GeP2S12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].02s/it, composition=Li7P3S11, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].19s/it, composition=Li1.4Al0.4Ti1.6(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].30s/it, composition=Li6.46Al0.15La3Zr1.9, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].39s/it, composition=Li3.25Ge0.25P0.75S4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].46s/it, composition=Li6.5La2.9Ba0.1Zr1.4, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].50s/it, composition=Li6.5La3Zr1.5Ta0.5O1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].52s/it, composition=La0.55Li0.361Ti0.995, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].54s/it, composition=La0.55Li0.36Ti0.992A, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].55s/it, composition=Li0.022 La0.117 Ti0., status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 15/15 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].60s/it, composition=Li0.24La0.59TiO3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].47it/s, composition="(Li2S)0.4 ((P2S5)0., status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]n=Li6.25Ba1.25La1.75Ta, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].19it/s, composition=Li5La3Ta2O12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].20it/s, composition="(LiCl)0.5 (P2O5)0.5, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 15/15 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].21it/s, composition="(LiCl)0.25 ((Li2O)0, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].59it/s, composition=Li0.7Al0.3Ti1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 8/8 [00:00<00:00, 15217.43it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].08it/s, composition=Li1.4S2.2P0.6, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].53it/s, composition="(Li2S)0.4 ((Ga2S3)0, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].06it/s, composition=Li6La2SrNb2O12, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].14s/it, composition=Li0.1Na0.1La0.6TiO3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].28s/it, composition=Li6BaLa2Ta2O12, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].37s/it, composition=Li6CaLa2Ta2O12, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 3/3 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].44s/it, composition=Li7La3Ta2O13, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].48s/it, composition=Li4.2Ge0.8Ga0.2S4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].51s/it, composition=Li1.076Al0.6923Ti1.4, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]n=Li1.5Al0.5Ge1.5(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]n=LiGe2(PO4)3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].26it/s, composition="(Li2O)50 (LiF)20 (P, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 25/25 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].08s/it, composition=Li9SiAlO8, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].24s/it, composition=Li6BaLa2Ta2O12, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 3/3 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].34s/it, composition=Li6SrLa2Ta2O12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].42s/it, composition=Li6Sr0.5Ba0.5La2Ta2O, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<00:00, 1986.41it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].46s/it, composition=Li3.2Ge0.2P0.8S4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].10s/it, composition="(Li2S)50 (P2S5)17 (, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].25s/it, composition=Li1.3Al0.1Sc0.2Ti1.7, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].34s/it, composition=Li1.3Al0.2Sc0.1Ti1.7, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 10/10 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].54s/it, composition=Li1.15Fe0.15Ti1.85(P, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].58s/it, composition=LiHfTi(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].57s/it, composition=Li0.2Zr1.2Nb0.8(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].56s/it, composition=Li1.6Ga0.6Ti1.4(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].56s/it, composition=Li1.2Sc0.2Ti1.8(PO4), status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].58s/it, composition=Li1.8Sc0.8Ti1.2(PO4), status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].59s/it, composition=Li1.3Sc0.3Ti1.7(PO4), status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].60s/it, composition=Li1.1Sc0.1Ti1.9(PO4), status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].59s/it, composition=Li1.2Sc0.2Ti1.6Zr0.2, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].57s/it, composition=Li1.3In0.3Hf1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].57s/it, composition=LiTi0.2Zr1.8(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].57s/it, composition=Li1.2Sc0.2Ti0.2Zr1.5, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].58s/it, composition=LiTi1.8Zr0.2(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].58s/it, composition=LiTi0.5Zr1.5(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].61s/it, composition=LiTiZr(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].59s/it, composition=LiTi0.1Zr1.9(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].58s/it, composition=Li1.2Al1.1Ta0.9(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].61s/it, composition=LiAlTa(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].64s/it, composition=Li1.5Cr0.5Ti1.5(PO4), status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].67s/it, composition=Li1.6Cr0.6Ti1.4(PO4), status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].68s/it, composition=Li1.3Cr0.3Ti1.7 (PO4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].64s/it, composition=Li1.3Cr0.3Ge1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].62s/it, composition=Li3Al0.4Sc1.6(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].61s/it, composition=Li1.2Fe0.2Hf1.8(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s].60s/it, composition=Li1.2In0.2Hf1.8(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=Li1.4In0.4Hf1.6(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=Li1.1Fe0.1Hf1.9(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=Li1.2Lu0.2Hf1.8(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=Li1.2Y0.2Hf1.8(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li1.1Y0.1Hf1.9(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.2Sc0.2Hf1.8(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.3Sc0.3Hf1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.1Lu0.1Hf1.9(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.4Y0.4Hf1.6(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.4Sc0.4Hf1.6(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li1.3Fe0.3Hf1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li1.3Lu0.3Hf1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.3Y0.3Hf1.7(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li1.1Sc0.1Hf1.9(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.4Lu0.4Hf1.6(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.1In0.1Hf1.9(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.3Cr0.3Hf1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.2Cr0.2Hf1.8(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.5Cr0.5Hf1.5(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.1Cr0.1Hf1.9(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 7/7 [00:00<?, ?it/s]on=Li1.3Eu0.3Ti1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.29s/it, composition=LiZr2(PO4)3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.38s/it, composition=LiHf2(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.45s/it, composition=Li1.15Y0.15Zr1.85(PO, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.50s/it, composition=Li1.02Zr1.98Y0.02(PO, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.52s/it, composition=Li0.9Zr1.9Nb0.1(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li0.98Zr1.98Nb0.02(P, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.3Al0.2Y0.1Ti1.7(, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.3Al0.1Y0.2Ti1.7(, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.3Al0.15Y0.15Ti1., status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.4Al0.4Ge0.2Ti1.4, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.55s/it, composition=Li1.4Al0.4Ge1.2Ti0.4, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.4Al0.4Ge1.6(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=Li2InTi(PO4)3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]on=Li2CrZr(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]on=Li2CrTi(PO4)3, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]on=Li2FeTi(PO4)3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.00it/s, composition=Li2FeZr(PO4)3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.20s/it, composition=Li2InZr(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.33s/it, composition=Li2InHf(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.40s/it, composition=Li1.7Al0.7Ge1.3(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.46s/it, composition=Li1.6Al0.6Ge1.4(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.48s/it, composition=Li1.3Al0.3Ge1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.50s/it, composition=Li1.7Al0.7Ti1.3(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.51s/it, composition=Li1.1Al0.1Ti1.9(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.53s/it, composition=Li1.1Al0.1Ge1.9(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.54s/it, composition=Li1.5Al0.5Ti1.5(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.54s/it, composition=Li1.05Al0.05Ti1.95(P, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.54s/it, composition=Li1.6Al0.6Ge0.8Ti0.6, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.4Al0.4Ge1.0Ti0.6, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.8Al0.8Ge0.8Ti0.4, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.4Al0.4Ge0.8Ti0.8, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.6Al0.6Ge1.0Ti0.4, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.2Al0.2Ge0.8Ti(PO, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li1.2Al0.2Ge1.0Ti0.8, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.8Al0.8Ge1.0Ti0.2, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.61s/it, composition=LiCrSb(PO4)3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.63s/it, composition=LiAlSb(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 6/6 [00:00<00:00, 5991.86it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.64s/it, composition=LiFeSb(PO4)3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.61s/it, composition=Li1.2Y0.2Ti1.8(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=Li1.4Y0.4Ti1.6(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=Li1.3Y0.3Ti1.7(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 10/10 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.66s/it, composition=Li1.2Fe0.2Ti1.8(PO4), status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.64s/it, composition=Li1.4Sc0.4Ti1.6(PO4), status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.62s/it, composition=Li1.2In0.2Ti1.8(PO4), status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 10/10 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.64s/it, composition=Li1.4Fe0.4Ti1.6(PO4), status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.62s/it, composition=Li1.4In0.4Ti1.6(PO4), status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=Li1.5In0.5Ti1.5(PO4), status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 10/10 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.63s/it, composition=Li1.5Fe0.5Ti1.5(PO4), status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.64s/it, composition=Li1.4Cr0.4Ti1.6(PO4), status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.62s/it, composition=Li1.5Y0.5Ti1.5(PO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.64s/it, composition=Li1.2Cr0.2Ti1.8(PO4), status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.61s/it, composition=Li1.2La0.2Ti1.8(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=Li1.3La0.3Ti1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=Li1.4La0.4Ti1.6(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 12/12 [00:00<?, ?it/s]=Li1.5La0.5Ti1.5(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.36s/it, composition=LiSn2(PO4)3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.42s/it, composition=Li1.3Sc0.3Ge1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.48s/it, composition=Li1.5Ga0.5Ge1.5(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.50s/it, composition=Li1.3Fe0.3Ge1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.51s/it, composition=Li1.5Sc0.5Ge1.5(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.53s/it, composition=Li1.7Fe0.7Ge1.3(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.54s/it, composition=Li1.7Ga0.7Ge1.3(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.55s/it, composition=Li1.3In0.3Ge1.7(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.5In0.5Ge1.5(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.45Al0.45Ge0.2Ti1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li1.40Al0.4Ge0.2Ti1., status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.50Al0.50Ge0.2Ti1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.35Al0.35Ge0.2Ti1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li1.55Al0.55Ge0.2Ti1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li1.45Al0.45Ti1.55(P, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li7Ge3PS12, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 70/70 [00:00<?, ?it/s]=Li3.2PO3.1N0.7, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=LiFePO4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]on=Li6PS5Cl, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li4P2S6, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 14/14 [00:00<?, ?it/s]="(Li2O)50((SeO2)0.5, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 7/7 [00:00<?, ?it/s]on=LiTi2P3O12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.37it/s, composition=LiZr2P3O12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.02it/s, composition=Li1.6Al0.6Ge1.4 (PO4, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<00:00, 526.36it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.16s/it, composition=Li6.25PS5.25Cl0.75, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]on=Li3.8Ge0.8P0.2O4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]on=Li3PO4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.06it/s, composition=Li3VO4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.14s/it, composition=Li3.2Ge0.2P0.8O4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 670/670 [00:00<00:00, 120335.02it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]2.37s/it, composition=Li3V0.6P0.4O4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 670/670 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]3.18s/it, composition=Li3P0.2V0.8O4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]2.70s/it, composition=Li3.6Ge0.6P0.4O4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]2.36s/it, composition=Li3.4Ge0.4P0.6O4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]2.15s/it, composition=Li3.2Ge0.2V0.8O4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]2.01s/it, composition=Li3.6Ge0.6V0.4O4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.90s/it, composition=Li3.8Ge0.8V0.2O4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.82s/it, composition=Li3.4Ge0.4V0.6O4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 670/670 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li3P0.6V0.4O4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]2.11s/it, composition=Li4GeO4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 670/670 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li3P0.8V0.2O4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]on=Li6PS5Br, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.81s/it, composition=Li6PS5I, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 9/9 [00:00<?, ?it/s]on="(Li2S)0.75 (P2S5)0., status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.07s/it, composition=LiBH4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.22s/it, composition=Li0.245La0.592Ti0.98, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.32s/it, composition=La0.55Li0.36Ti0.995A, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 15/15 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.42s/it, composition=La0.54Li0.36TiO3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.46s/it, composition=La0.51Li0.36Ti0.95W0, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.51s/it, composition=La0.56Li0.36Ti0.95Al, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.53s/it, composition=La0.55Li0.36Ti0.95Ge, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.54s/it, composition=La0.58Li0.36Ti0.95Mg, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.55s/it, composition=La0.55Li0.36Ti0.95Mn, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.55s/it, composition=La0.55Li0.36Ti0.95Ru, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 15/15 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=Li0.34La0.51TiO2.94, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 15/15 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.62s/it, composition=(La0.5Li0.5)TiO3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=Sm0.52Li0.38TiO2.97, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 15/15 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.62s/it, composition=Li0.10La0.63TiO3, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.61s/it, composition=(La0.5Li0.5)0.75(La0, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=Li0.34Pr0.56TiO3, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=Nd0.55Li0.34TiO3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li0.5(La0.4Nd0.1)TiO, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 15/15 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=Li0.34La0.56TiO3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=Nd0.25Li0.25TaO3, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 3/3 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=Li0.25La0.25TaO3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li0.5Sr0.5Cr0.25Ta0., status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li0.5Sr0.5Fe0.25Ta0., status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 14/14 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.62s/it, composition=La0.29Li0.12NbO3, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 14/14 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.65s/it, composition=La0.283Li0.15NbO3, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 14/14 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.66s/it, composition=La0.273Li0.18NbO3, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 14/14 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.66s/it, composition=La0.303Li0.09NbO3, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 14/14 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.67s/it, composition=La0.313Li0.06NbO3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.65s/it, composition=Li0.1Sr0.8Ti0.7Nb0.3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.63s/it, composition=Li0.3Sr0.6Ti0.20Fe0., status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.62s/it, composition=Li0.3Sr0.6Ti0.35Fe0., status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=Li0.3Sr0.6Ti0.40Fe0., status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=Li0.3Sr0.6Ti0.45Fe0., status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=Li0.3Sr0.6Ti0.5Ta0.5, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li0.3Sr0.6Ti0.5Nb0.5, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li0.25La0.41Sr0.25Ti, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li0.15La0.51Sr0.15Ti, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=LiSrTiTaO6, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=LiSr1.65Ti1.3Ta1.7O9, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=LiSr1.65Ti1.3Nb1.7O9, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=LiSr1.65Zr1.3Ta1.7O9, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=LiSr2Ti2TaO9, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.61s/it, composition=LiSr2Ti2NbO9, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.64s/it, composition=LiSrTiNbO6, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 3/3 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.63s/it, composition=LiBa2Ti2NbO9, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 15/15 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.64s/it, composition=Li0.067La0.64TiO2.99, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.61s/it, composition=Li0.25La0.66Ti0.75Al, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=Li0.20La0.66Ti0.80Al, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=Li0.30La0.66Ti0.70Al, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li0.15La0.66Ti0.85Al, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=Li0.10La0.66Ti0.90Al, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li0.06La0.66Ti0.93Al, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 15/15 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.61s/it, composition=Li0.27La0.59TiO3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li3O(Cl0.5Br0.5), status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]on=Li3OCl, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.07s/it, composition=Li10SnP2S12, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 15/15 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.25s/it, composition=Li0.36La0.55TiO3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.00it/s, composition="(Li2S)70 (P2S5)30", status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.16s/it, composition=Li11AlP2S12, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]on=Li5NI2, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]on=Li6NBr3, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]on=Li4SiO4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.20it/s, composition=Li2Ge7O15, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 3/3 [00:00<?, ?it/s]on=Li3.5Ge0.5V0.5O4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=LiI, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]on=Li3P, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.32it/s, composition=Li3Sc2P3O12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]on=Li5La3Bi2O12, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=LiLa(TiO3)2, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 6/6 [00:00<?, ?it/s]on=Li4BN3H10, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.36it/s, composition=Li2NH, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]on=Li2Ca(NH)2, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.15it/s, composition=Li3N, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 4/4 [00:00<?, ?it/s]on=Li13.6Si2.8S1.2O16, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=LiAlH4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.22it/s, composition=Li4B7O12Cl, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.06s/it, composition=Li10.35Si1.35P1.65S1, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]on=Li9.81Sn0.81P2.19S12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.06s/it, composition=Li5La3Nb2O12, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<00:00, 8345.21it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.22s/it, composition=Li14ZnGe4O16, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.34s/it, composition=Li2.88PO3.73N0.14, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.45s/it, composition=Li6.35P0.65Si0.35S5B, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.50s/it, composition=Li6.50P0.50Si0.50S5B, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.52s/it, composition=Li6.20P0.80Si0.20S5B, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.53s/it, composition=Li6.30P0.70Si0.30S5B, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.54s/it, composition=Li6.25P0.75Si0.25S5B, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.54s/it, composition=Li6.12P0.90Si0.12S5B, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.55s/it, composition=Li6.22P0.78Si0.22S5B, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.55s/it, composition=Li6.17P0.83Si0.17S5B, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li6.13P0.87Si0.13S5B, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li6.08P0.92Si0.08S5B, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.56s/it, composition=Li6.02P0.98Si0.02S5, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li6.10P0.90Si0.10S5B, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li6.05P0.95Si0.05S5B, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li3.6Si0.6P0.4S4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li4SiS4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.30s/it, composition=Li2SiS3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.38s/it, composition=Li6.75La3Zr1.75Nb0.2, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.43s/it, composition=Li7La3Zr1.89Al0.15O1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.47s/it, composition=Li6.75La3Zr1.875Te0., status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.50s/it, composition=Li10Ge0.95Si0.05P2S1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.52s/it, composition=Li5.5La3Nb1.75In0.25, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li5.5La2.75K0.25Nb2O, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li7La3Zr2O12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.04s/it, composition=Li7La3Hf2O12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.20s/it, composition=Li6.25La3Zr2Ga0.25O1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 3/3 [00:00<?, ?it/s]on=Li2.2Zn0.1Zr0.9S3, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.11s/it, composition=Li4GeS4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.26s/it, composition=Li4PS4I, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.35s/it, composition=Li6.6La2.75Y0.25Zr1., status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.43s/it, composition=Li6.6La2.875Y0.125Zr, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li6.6La2.5Y0.5Zr1.6T, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.21s/it, composition=Li4SnS4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li6.4La3Zr2Ga0.2O12, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 3/3 [00:00<?, ?it/s]on=Li2SnS3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.04it/s, composition=Li3PS4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.15s/it, composition=Li6.5La3Nb1.25Y0.75O, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.27s/it, composition=Li6La3Nb1.5Y0.5O12, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.36s/it, composition=Li6.5La3Zr1.5Ta0.5O1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.42s/it, composition=Li6.6La3Zr1.6Ta0.4O1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.47s/it, composition=Li6.7La3Zr1.7Ta0.3O1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.51s/it, composition=Li6.2La3Zr1.2Ta0.8O1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.54s/it, composition=Li6.8La3Zr1.8Ta0.2O1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.55s/it, composition=Li6La3ZrTaO12, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.55s/it, composition=Li6.6La3Zr1.6Sb0.4O1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.55s/it, composition=Li6.4La3Zr1.4Sb0.6O1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.55s/it, composition=Li6.2La3Zr1.2Sb0.8O1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li6La3ZrSbO12, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li6.8La3Zr1.8Sb0.2O1, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.32s/it, composition=Li5La3Ta2O12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.40s/it, composition=Li6BaLa2Nb2O12, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.46s/it, composition=Li6SrLa2Nb2O12, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.50s/it, composition=Li6CaLa2Nb2O12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]on=Li6.75La3Zr1.75Ta0.2, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.24s/it, composition=Li10SiP2S12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]2.97it/s, composition="(Li2S)(LaOI)", status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.40it/s, composition=Li3.9Zn0.05GeS4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]2.59it/s, composition="(Li0.5La0.5TiO3)95(, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.32it/s, composition=Li4.275Ge0.61Ga0.25S, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.01s/it, composition=Li1.4Ti1.6In0.4P3O12, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 5/5 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.13it/s, composition="((Li2S)0.6 (SiS2)0., status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.10s/it, composition=Li6La2Ca(Nb)2O12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.25s/it, composition=Li6MgLa2Ta2O12, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.35s/it, composition=Li4.4Al0.4Ge0.6S4, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.42s/it, composition=Li4.4Al0.4Sn0.6S4, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.48s/it, composition=Li4.4Ga0.4Ge0.6S4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.50s/it, composition=Li4.4Ga0.4Sn0.6S4, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li5AlS4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.30s/it, composition=LiMgPO4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.40s/it, composition=Li0.95Mg0.95In0.05PO, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.46s/it, composition=Li0.9Mg0.9In0.1PO4, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.50s/it, composition=Li0.85Mg0.85In0.15PO, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li0.83Mg0.83In0.17PO, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.63s/it, composition=Li3AlS3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.61s/it, composition=Li6SiO4Cl2, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.61s/it, composition=LiTa2PO8, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li0.022 La0.118 Ti0., status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.59s/it, composition=Li2ZrS3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li0.022 La0.115 Ti0., status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 3/3 [00:00<00:00, 5866.16it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=(YPO4)0.8(Li3PO4)0.2, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li0.8La0.066Zr2(PO4, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li3.09BO2.53N0.52, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li5Nd3Sb2O12, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 4/4 [00:00<?, ?it/s]on=Li5La3Sb2O12, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 18/18 [00:00<?, ?it/s]="(Li2O)16.6 (SiO2)83, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.23it/s, composition=Li3Fe2P3O12, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.03s/it, composition=Li2.9Sc1.9Zr0.1(PO4), status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 14/14 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.22s/it, composition=Li1.9Mg0.1TiO3.05, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 3/3 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.32s/it, composition=(YPO4)0.9(Li3PO4)0.1, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 3/3 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.41s/it, composition=(YPO4)0.7(Li3PO4)0.3, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 3/3 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=(YPO4)0.5(Li3PO4)0.5, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.23s/it, composition=LiGaSiO4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.33s/it, composition=Li0.68Ga0.68Si2.33O6, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.40s/it, composition=Li0.96Ga0.96Si2.04O6, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.45s/it, composition=Li4Al0.33Si0.33P0.33, status=Not Found]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.48s/it, composition=Li4Al0.33Si0.17Ge0.1, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 25/25 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.57s/it, composition=Li4.25Si0.75Al0.25O4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.58s/it, composition=Li3.75Si0.75P0.25O4, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.61s/it, composition=LiCaTiNbO6, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.60s/it, composition=Li3Cr(MoO4)3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li2Mg2(MoO4)3, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li3Fe(MoO4)3, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.07s/it, composition=Li6FeCl8, status=Success]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.21s/it, composition=Li4.8Si0.2Al0.8S4, status=Not Found]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]1.32s/it, composition=Li3.6Ge0.4P0.6S4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li3.35Ge0.35P0.65S4, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 1/1 [00:00<?, ?it/s]on=Li6NiCl8, status=Success]
# Retrieving SummaryDoc documents: 100%|██████████| 3/3 [00:00<?, ?it/s]on=Li6CoCl8, status=Success]
# 正在下载CIF文件: 100%|██████████| 422/422 [09:47<00:00,  1.39s/it, composition=LiF, status=Success]
# ==================================================
# 处理完成！
# 成功下载: 167 个结构的CIF文件
# 未找到或出错: 255 个化学成分
# 所有CIF文件已保存在: d:\学习相关文档\大三上\大数据与机器智能\大作业\mattergen\downloaded_cifs
# 详细下载日志已保存在: d:\学习相关文档\大三上\大数据与机器智能\大作业\mattergen\downloaded_cifs\download_summary.csv
# ==================================================

# %%
from data_process import CrystalDataProcessor
processor = CrystalDataProcessor(
    cif_dir="results/generated_crystals_cif.zip",
    conductivity_file="extracted_conductivity.csv",
    output_dir="processed_data",
    cutoff_radius=8.0
)
processor.run()
# Out:
# 2025-09-07 11:37:08,880 - data_process - INFO - Starting preprocessing pipeline
# 2025-09-07 11:37:08,880 - data_process - INFO - Extracting CIF files from results/generated_crystals_cif.zip
# 2025-09-07 11:37:08,892 - data_process - INFO - Found 337 CIF files to process
# 2025-09-07 11:37:08,892 - data_process - INFO - Loaded conductivity data for 321 materials
# 2025-09-07 11:37:08,897 - data_process - INFO - Renamed column 'ID' to 'material_id'
# 2025-09-07 11:37:08,897 - data_process - INFO - Renamed column 'Ionic conductivity (S cm-1)' to 'conductivity'
# 2025-09-07 11:37:08,899 - data_process - INFO - Created log-transformed conductivity for 321 entries
# Processing CIF files:   0%|          | 0/337 [00:00<?, ?it/s]d:\学习相关文档\大三上\大数据与机器智能\大作业\mattergen\data_process.py:266: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   node_positions = torch.tensor(node_positions, dtype=torch.float)
# Processing CIF files: 100%|██████████| 337/337 [07:35<00:00,  1.35s/it]
# 2025-09-07 11:44:44,341 - data_process - INFO - Successfully processed 337 CIF files
# 2025-09-07 11:44:44,341 - data_process - INFO - Failed to process 0 CIF files
# Saving processed data: 100%|██████████| 337/337 [00:00<00:00, 1088.30it/s]
# 2025-09-07 11:44:44,652 - data_process - INFO - Saved 321 graphs with conductivity data
# 2025-09-07 11:44:44,652 - data_process - INFO - Saved 16 graphs without conductivity data
# 2025-09-07 11:44:44,654 - data_process - INFO - Created dataset splits: 257 train, 32 validation, 32 test
# 2025-09-07 11:44:44,656 - data_process - INFO - Calculating feature statistics for normalization
# 2025-09-07 11:44:44,684 - data_process - INFO - Node feature mean: tensor([11.3509,  1.1228,  2.0392,  3.2243,  0.4271])
# 2025-09-07 11:44:44,686 - data_process - INFO - Node feature std: tensor([15.0944,  0.4317,  1.1105,  2.4950,  0.4947])
# 2025-09-07 11:44:44,694 - data_process - INFO - Edge feature mean: tensor([5.5074])
# 2025-09-07 11:44:44,695 - data_process - INFO - Edge feature std: tensor([1.5597])
# 2025-09-07 11:44:44,696 - data_process - INFO - Preprocessing completed successfully
# 2025-09-07 11:44:44,696 - data_process - INFO - Results saved to processed_data
# {'status': 'success',
#  'total_processed': 337,
#  'with_conductivity': 321,
#  'without_conductivity': 16,
#  'train_size': 257,
#  'val_size': 32,
#  'test_size': 32,
#  'output_dir': 'processed_data'}
